# %% [markdown]
# Exercise 1

# %%
print('Hello world!') #the letter "P" should not be capitalized
# Out:
# Hello world!

# %%
print('Hello world!') # missing "("
# Out:
# Hello world!

# %%
print('Hello world!') # missing "'"
# Out:
# Hello world!

# %%
print('Hello world!') # it has a another symbol "'"
# Out:
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x) #the final answer is 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = x + 1
print(x) #in the solution x = x = 1 the letter "X" should not be capitalized

# %%
# !git config --global user.name =  'Simon Cris Deanon' #your full name
# !git config --global user.email = 'deanonsimoncris@gmail.com' #the email address you used in creating your GitHub account
#!git config --global user.password = 'xxx your TOKEN xxx' #password should be the token

# %%
# !git clone https://github.com/Simon-cris123/ICT110_CS2A_Deanon-.git
# Out:
# Cloning into 'ICT110_CS2A_Deanon-'...
# ...
